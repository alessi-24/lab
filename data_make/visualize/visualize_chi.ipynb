# %%
#package
using Distributions
using Random
using LinearAlgebra
using Plots
using StatsBase
using LaTeXStrings
using DataFrames
using CSV
using Base.Threads
using HDF5
gr()
# Out:
# Plots.GRBackend()

# %%
function read_file(file_path)
    file = h5open(file_path, "r")
    chi_Temp_inv = read(file, "chi_inv")
    return chi_Temp_inv
end
# Out:
# read_file (generic function with 1 method)

# %%
function visualize(chi_Temp_inv)
    # 温度設定
    Temp_table_chi = collect(0.2:0.2:70)
    plot(
        Temp_table_chi, chi_Temp_inv,
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
        label="Observed data",
        st=:scatter,
        markersize=0.5,
        framestyle = :box,
        title = L"\sigma=0",
    )
end
# Out:
# visualize (generic function with 2 methods)

# %% [markdown]
# 真値のデータのみ

# %%
read_file_path = "/Users/test/home/lab_research_1/data_make/data/chi_inv/chi_inv.h5"
chi_Temp_inv = read_file(read_file_path)
visualize(chi_Temp_inv)

# %%
save_path_png = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv.png"
save_path_pdf = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv.pdf"
savefig(save_path_png)
savefig(save_path_pdf)
# Out:
# "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv.pdf"

# %% [markdown]
# 全部のデータをプロットしてみる

# %%
# ノイズ入りデータ
chi_Temp_inv_noise = zeros(350,5)

for i in 1:5
    read_file_path = "/Users/test/home/lab_research_1/data_make/data/chi_inv/chi_inv_" *string(i)* ".h5"
    chi_Temp_inv_noise[:,i] = read_file(read_file_path)
end

# %%
# 行列入力
function visualize_all(chi_Temp_inv)
    # 温度設定
    Temp_table_chi = collect(0.2:0.2:70)

    plt = plot(
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
    )

    for i in 1:size(chi_Temp_inv)[2]
        plot!(
            Temp_table_chi, chi_Temp_inv[:,i],
            st=:scatter,
            markersize=1.5,
        )
    end
    plot(plt)
end
# Out:
# visualize_all (generic function with 1 method)

# %%
visualize_all(chi_Temp_inv_noise)

# %% [markdown]
# 各ノイズデータをプロットしていく

# %%
Temp_table_chi = collect(0.2:0.2:70)
plot(
        Temp_table_chi, chi_Temp_inv_noise[:,1],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
        label="Observed data",
        st=:scatter,
        markersize=0.5,
        framestyle = :box,
        title = L"\sigma=10^{-1.0}",
    )

# %%
save_path_png = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_1.png"
save_path_pdf = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_1.pdf"
savefig(save_path_png)
savefig(save_path_pdf)
# Out:
# "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_1.pdf"

# %%
Temp_table_chi = collect(0.2:0.2:70)
plot(
        Temp_table_chi, chi_Temp_inv_noise[:,2],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
        label="Observed data",
        st=:scatter,
        markersize=0.5,
        framestyle = :box,
        title = L"\sigma=10^{-0.5}",
    )

# %%
save_path_png = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_2.png"
save_path_pdf = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_2.pdf"
savefig(save_path_png)
savefig(save_path_pdf)
# Out:
# "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_2.pdf"

# %%
Temp_table_chi = collect(0.2:0.2:70)
plot(
        Temp_table_chi, chi_Temp_inv_noise[:,3],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
        label="Observed data",
        st=:scatter,
        markersize=0.5,
        framestyle = :box,
        title = L"\sigma=10^{0.0}",
    )

# %%
save_path_png = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_3.png"
save_path_pdf = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_3.pdf"
savefig(save_path_png)
savefig(save_path_pdf)
# Out:
# "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_3.pdf"

# %%
Temp_table_chi = collect(0.2:0.2:70)
plot(
        Temp_table_chi, chi_Temp_inv_noise[:,4],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
        label="Observed data",
        st=:scatter,
        markersize=0.5,
        framestyle = :box,
        title = L"\sigma=10^{0.5}",
    )

# %%
save_path_png = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_4.png"
save_path_pdf = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_4.pdf"
savefig(save_path_png)
savefig(save_path_pdf)
# Out:
# "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_4.pdf"

# %%
Temp_table_chi = collect(0.2:0.2:70)
plot(
        Temp_table_chi, chi_Temp_inv_noise[:,5],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$1/\chi$ (mol/emu)",
        label="Observed data",
        st=:scatter,
        markersize=0.5,
        framestyle = :box,
        title = L"\sigma=10^{1.0}",
    )

# %%
save_path_png = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_5.png"
save_path_pdf = "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_5.pdf"
savefig(save_path_png)
savefig(save_path_pdf)
# Out:
# "/Users/test/home/lab_research_1/data_make/visualize/chi_inv/chi_inv_5.pdf"
