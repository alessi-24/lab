# %%
#package
using Distributions
using Random
using LinearAlgebra
using Plots
using StatsBase
using LaTeXStrings
using DataFrames
using CSV
using Base.Threads
using HDF5
gr()
# Out:
# Plots.GRBackend()

# %%
para_file = h5open("/Users/nishimura/home/lab/3para/exmc/result/spc/spc8_para.h5", "r")
    para_B20 = read(para_file, "B20")
    para_B40 = read(para_file, "B40")
    para_B44 = read(para_file, "B44")

close(para_file)

# %%
para_B20
# Out:
# 100×72 Matrix{Float64}:
#   0.146017   -0.0719219  -0.134209   …   0.161266   0.0477312  -0.262623
#   0.146017   -0.0719219  -0.134209       0.161266   0.0477312  -0.262623
#   0.142729   -0.0706062  -0.132592       0.161246   0.0476423  -0.262595
#   0.142729   -0.0706062  -0.132592       0.161246   0.0476423  -0.262595
#   0.135476   -0.0788263  -0.140107       0.161409   0.0477899  -0.262587
#  -0.0788263  -0.140107    0.189018   …   0.161409   0.0477899  -0.262587
#  -0.0805864  -0.134126    0.192231       0.161315   0.0478551  -0.262574
#  -0.0825798  -0.137777    0.185507       0.161147   0.0478147  -0.262697
#  -0.0799412  -0.141656    0.183649       0.161182   0.0477621  -0.262825
#  -0.0799412  -0.141656    0.183649       0.161182   0.0477621  -0.262825
#  -0.141656    0.183649   -0.0799412  …   0.161182   0.0477621  -0.262825
#  -0.149029    0.182676   -0.0848751      0.16119    0.0477144  -0.26293
#  -0.150231    0.182923   -0.0797412      0.161221   0.0478796  -0.262858
# ...

# %%
acex_file = h5open("/Users/nishimura/home/lab/3para/exmc/result/spc/spc8_ac_ex.h5", "r")
    ac = read(acex_file, "ac")
    ex = read(acex_file, "ex")

close(acex_file)

# %%
plot(ac)

# %%
plot(ex[1:end-1])

# %%
plot(
    para_B20[:,1],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B40[:,1],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B44[:,1],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B20[:,end],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B40[:,end],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B44[:,end],
    st = :scatter,
    color = :black,
)
