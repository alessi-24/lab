# %%
#package
using Distributions
using Random
using LinearAlgebra
using Plots
using StatsBase
using LaTeXStrings
using DataFrames
using CSV
using Base.Threads
using HDF5
gr()
# Out:
# Plots.GRBackend()

# %%
para_file = h5open("/Users/nishimura/home/lab/3para/exmc/result/spc/spc3_para.h5", "r")
    para_B20 = read(para_file, "B20")
    para_B40 = read(para_file, "B40")
    para_B44 = read(para_file, "B44")

close(para_file)

# %%
B20_true = 0.381
    B40_true = 0.165
    B44_true = 0.447
# Out:
# 0.447

# %%
para_B20
# Out:
# 1000×72 Matrix{Float64}:
#  0.466324   0.20701    0.138129  0.311408  …  0.252572  0.153494  0.194947
#  0.466324   0.20701    0.138129  0.311408     0.252572  0.153494  0.194947
#  0.467678   0.208175   0.13895   0.311326     0.252572  0.153502  0.194948
#  0.466765   0.207926   0.137632  0.310068     0.252563  0.153502  0.194959
#  0.467484   0.207771   0.137121  0.310196     0.252563  0.153502  0.194974
#  0.467484   0.207771   0.137121  0.310196  …  0.252563  0.153502  0.194974
#  0.467484   0.207771   0.137121  0.310196     0.252563  0.153502  0.194974
#  0.467484   0.207771   0.137121  0.310196     0.252563  0.153502  0.194974
#  0.46717    0.208247   0.137392  0.310307     0.252563  0.153513  0.194977
#  0.467587   0.208206   0.136638  0.310466     0.252547  0.15353   0.194982
#  0.467587   0.208206   0.136638  0.310466  …  0.252547  0.15353   0.194982
#  0.467587   0.208206   0.136638  0.310466     0.252547  0.15353   0.194982
# ...

# %%
acex_file = h5open("/Users/nishimura/home/lab/3para/exmc/result/spc/spc3_ac_ex.h5", "r")
    ac = read(acex_file, "ac")
    ex = read(acex_file, "ex")

close(acex_file)

# %%
plot(ac)

# %%
plot(ex[1:end-1])

# %%
plot(
    para_B20[:,1],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B40[:,1],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B44[:,1],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B20[:,end],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B40[:,end],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B44[:,end],
    st = :scatter,
    color = :black,
)

# %%
plot(
    para_B20[:,end],
    st = :histogram,
    color=:black,
)

# %%
plot(
    para_B40[:,end],
    st = :histogram,
    color=:black,
)

# %%
plot(
    para_B44[:,end],
    st = :histogram,
    color=:black,
)
