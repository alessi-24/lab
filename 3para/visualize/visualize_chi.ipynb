# %%
#package
using Distributions
using Random
using LinearAlgebra
using Plots
using StatsBase
using LaTeXStrings
using DataFrames
using CSV
using Base.Threads
using HDF5
gr()
# Out:
# Plots.GRBackend()

# %%
function read_file_chi(file_path)
    file = h5open(file_path, "r")
    data = read(file, "chi")
    return data
end
# Out:
# read_file_chi (generic function with 1 method)

# %%
read_file_path = "/Users/nishimura/home/lab/3para/data_make/data/chi/chi.h5"
chi_Temp_inv = read_file_chi(read_file_path)
# Out:
# 350-element Vector{Float64}:
#   0.4569525790499862
#   0.9094566438904416
#   1.3579340981127732
#   1.8023901238809357
#   2.2428689906894075
#   2.6794206800620124
#   3.1120961350839176
#   3.5409460882823565
#   3.9660206843166828
#   4.38736934070605
#   4.805040694472149
#   5.219082582752841
#   5.629542034051455
#   ⋮
#  88.70934782386752
#  88.95421691285233
#  89.19910795706484
#  89.44402078188216
#  89.68895521437213
#  89.93391108319616
#  90.17888821889859
#  90.42388645361966
#  90.66890562106127
#  90.9139455566712
#  91.15900609754547
#  91.40408708208255

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv,
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=0",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi.pdf"

# %%
# データ読み込み
chi_Temp_inv_noise = zeros(350,9)

for i in 1:9
    read_file_path = "/Users/nishimura/home/lab/3para/data_make/data/chi/chi_" *string(i)* ".h5"
    chi_Temp_inv_noise[:,i] = read_file_chi(read_file_path)
end

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
    Temp_table, chi_Temp_inv_noise[:,1],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{-3.0}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_1.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_1.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,2],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{-2.5}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_2.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_2.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,3],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{-2.0}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_3.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_3.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,4],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{-1.5}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_4.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_4.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,5],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{-1.0}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_5.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_5.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,6],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{-0.5}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_6.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_6.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,7],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{0.0}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_7.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_7.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,8],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{0.5}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_8.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_8.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
    Temp_table, chi_Temp_inv_noise[:,9],
    color="black",
    xlabel=L"$T$ (K)",
    ylabel=L"$1/\chi$ (mol/emu)",
    label="Observed data",
    st=:scatter,
    markersize=1.3,
    framestyle = :box,
    title = L"\sigma=10^{1.0}",
)

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/chi/chi_9.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/chi/chi_9.pdf"
