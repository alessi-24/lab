# %%
#package
using Distributions
using Random
using LinearAlgebra
using Plots
using StatsBase
using LaTeXStrings
using DataFrames
using CSV
using Base.Threads
using HDF5
gr()
# Out:
# Plots.GRBackend()

# %%
function read_file_spc(file_path)
    file = h5open(file_path, "r")
    data = read(file, "spc")
    return data
end
# Out:
# read_file_spc (generic function with 1 method)

# %%
read_file_path = "/Users/nishimura/home/lab/3para/data_make/data/spc/spc.h5"
SpcHeat_Temp = read_file_spc(read_file_path);

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plot(
        Temp_table, SpcHeat_Temp,
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=0",
    )

plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc.pdf"

# %%
# データ読み込み
SpcHeat_Temp_noise = zeros(350,11)

for i in 1:11
    read_file_path = "/Users/nishimura/home/lab/3para/data_make/data/spc/spc_" *string(i)* ".h5"
    SpcHeat_Temp_noise[:,i] = read_file_spc(read_file_path)
end

# %%
noise_list = [10^(-4.0), 10^(-3.5),10^(-3.0), 10^(-2.5), 10^(-2.0), 10^(-1.5), 10^(-1.0), 10^(-0.5), 10^(0.0)]
# Out:
# 9-element Vector{Float64}:
#  0.0001
#  0.00031622776601683794
#  0.001
#  0.0031622776601683794
#  0.010000000000000002
#  0.03162277660168379
#  0.1
#  0.31622776601683794
#  1.0

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,1],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-4.0}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_1.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_1.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,2],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-3.5}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_2.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_2.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,3],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-3.0}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_3.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_3.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,4],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-2.5}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_4.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_4.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,5],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-2.0}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_5.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_5.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,6],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-1.5}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_6.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_6.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,7],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-1.0}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_7.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_7.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,8],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{-0.5}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_8.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_8.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,9],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{0.0}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_9.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_9.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,10],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{0.5}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_10.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_10.pdf"

# %%
# 温度設定
Temp_table = collect(0.2:0.2:70)
plt = plot(
        Temp_table, SpcHeat_Temp_noise[:,11],
        color="black",
        xlabel=L"$T$ (K)",
        ylabel=L"$C$ (J(mol $\cdot$ K))",
        label="Observed data",
        st=:scatter,
        markersize=1.3,
        framestyle = :box,
        title = L"\sigma=10^{1.0}",
    )

plt = plot!(
    grid = false,
    xtickfont = font(13),
    ytickfont = font(13),
    guidefont = font(13),
    legendfont = font(10),
)

# %%
save_path = "/Users/nishimura/home/lab/3para/visualize/spc/spc_11.pdf"
savefig(save_path)
# Out:
# "/Users/nishimura/home/lab/3para/visualize/spc/spc_11.pdf"
